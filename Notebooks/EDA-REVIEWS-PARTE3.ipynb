# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
ruta = r'..\Yelp\reviews_parte3.csv'

# %%
df = pd.read_csv(ruta)

# %%
df.head(3)
# Out:
#               business_id  stars  \
# 0  IPNAySCrfEUTBnxh1kZq4A      5
# 1  1RUStfReoIm_8NzWXKSbCA      3
# 2  iW3Jo9r_y671fXCBa3uXeA      5
#
#                                                 text                 date
# 0  Brent is a true healer. His bodywork is transf...  2021-03-13 19:13:56
# 1  The restaurant has a very city bar vibe, with ...  2021-11-02 00:47:26
# 2  My guy and I love their juices and smoothies. ...  2021-11-02 20:28:29

# %%
df.describe()
# Out:
#             stars
# count 2063877.000
# mean        3.748
# std         1.514
# min         1.000
# 25%         3.000
# 50%         4.000
# 75%         5.000
# max         5.000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2063877 entries, 0 to 2063876
# Data columns (total 4 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   business_id  object
#  1   stars        int64
#  2   text         object
#  3   date         object
# dtypes: int64(1), object(3)
# memory usage: 63.0+ MB

# %%
#VERIFICAMOS QUE LA COLUMNA DATE TENGA TIPO DE DATO DATETIME
df['date'] = pd.to_datetime(df['date'])

#creamos una columna con años
df['year'] = df['date'].dt.year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2063877 entries, 0 to 2063876
# Data columns (total 5 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   business_id  object
#  1   stars        int64
#  2   text         object
#  3   date         datetime64[ns]
#  4   year         int32
# dtypes: datetime64[ns](1), int32(1), int64(1), object(2)
# memory usage: 70.9+ MB

# %%
plt.figure(figsize=(8, 4))
df['stars'].value_counts().sort_index().plot(kind='bar')
plt.title('Distribución de calificaciones')
plt.xlabel('Estrellas')
plt.ylabel('Número de comentarios')
plt.show()

# %%
plt.figure(figsize=(7, 4))
df['year'].value_counts().sort_index().plot(kind='bar')
# Añadir títulos y etiquetas
plt.title('Histograma de Datos por Año')
plt.xlabel('Año')
plt.ylabel('Frecuencia')

# Mostrar el gráfico
plt.show()

# %%
# Calcular el promedio de estrellas por año
average_stars_per_year = df.groupby('year')['stars'].mean().reset_index()

# Crear el gráfico de barras para mostrar el promedio de estrellas por año
plt.figure(figsize=(7, 6))
plt.plot(average_stars_per_year['year'], average_stars_per_year['stars'], linestyle='--', marker='o', color='blue')
plt.xticks(rotation=65)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xlabel('Año')
plt.ylabel('Promedio de Estrellas')
plt.title('Promedio de Estrellas por Año')

plt.show()
