# %%
import pandas as pd
import numpy as np

# %%
df_reviews=pd.read_json(r'C:\Users\Fernando\Desktop\Proyecto-Google-Yelp-Henry-\Datasets yelp\review.json',lines=True,encoding='latin1')

# %%
df_business=pd.read_pickle(r'C:\Users\Fernando\Desktop\Proyecto-Google-Yelp-Henry-\Datasets yelp\business.pkl')

# %%
df_business
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1       87 Grasso Plaza Shopping Center         Affton   NaN       63123
# ...

# %%
df_business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150346 entries, 0 to 150345
# Data columns (total 28 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   150346 non-null  object
#  1   name          150346 non-null  object
#  2   address       150346 non-null  object
#  3   city          150346 non-null  object
#  4   state         150343 non-null  object
#  5   postal_code   150346 non-null  object
#  6   latitude      150346 non-null  object
#  7   longitude     150346 non-null  object
#  8   stars         150346 non-null  object
#  9   review_count  150346 non-null  object
#  10  is_open       150346 non-null  object
#  11  attributes    136602 non-null  object
#  12  categories    150243 non-null  object
#  13  hours         127123 non-null  object
#  14  business_id   5 non-null       object
#  15  name          5 non-null       object
#  16  address       5 non-null       object
# ...

# %%
df_business.columns
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'categories', 'hours', 'business_id', 'name', 'address',
#        'city', 'state', 'postal_code', 'latitude', 'longitude', 'stars',
#        'review_count', 'is_open', 'attributes', 'categories', 'hours'],
#       dtype='object')

# %%
df_business=df_business.iloc[:,0:14] #las columnas venian duplicadas, asi que borramos la segunda mitad
df_business
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1       87 Grasso Plaza Shopping Center         Affton   NaN       63123
# ...

# %%
df_business[['latitude','longitude','stars']]=df_business[['latitude','longitude','stars']].astype(float)
df_business['review_count']=df_business['review_count'].astype(int)
# Out:
# C:\Users\Fernando\AppData\Local\Temp\ipykernel_22168\2388188542.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_business[['latitude','longitude','stars']]=df_business[['latitude','longitude','stars']].astype(float)
# C:\Users\Fernando\AppData\Local\Temp\ipykernel_22168\2388188542.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_business['review_count']=df_business['review_count'].astype(int)

# %%
df_business.drop(['is_open','attributes','hours'],axis=1,inplace=True)
# Out:
# C:\Users\Fernando\AppData\Local\Temp\ipykernel_22168\3863295400.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_business.drop(['is_open','attributes','hours'],axis=1,inplace=True)

# %%
df_business['state'].value_counts() #deberia haber 50
# Out:
# state
# PA     34039
# FL     26329
# TN     12056
# IN     11246
# MO     10913
# LA      9924
# AZ      9912
# NJ      8536
# NV      7715
# AB      5573
# CA      5203
# ID      4467
# DE      2265
# IL      2144
# TX         4
# CO         3
# HI         2
# MA         2
# WA         2
# UT         1
# NC         1
# MI         1
# MT         1
# SD         1
# XMS        1
# VI         1
# VT         1
# Name: count, dtype: int64

# %%
df_business['categories']=df_business['categories'].str.split(',').str[0]
df_business
# Out:
# C:\Users\Fernando\AppData\Local\Temp\ipykernel_22168\1069112568.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_business['categories']=df_business['categories'].str.split(',').str[0]
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# ...

# %%
df_business.isnull().sum()
# Out:
# business_id       0
# name              0
# address           0
# city              0
# state             3
# postal_code       0
# latitude          0
# longitude         0
# stars             0
# review_count      0
# categories      103
# dtype: int64

# %%
df_business.fillna('',inplace=True)
# Out:
# C:\Users\Fernando\AppData\Local\Temp\ipykernel_22168\3087806484.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_business.fillna('',inplace=True)

# %%
df_business
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara             93101
# 1       87 Grasso Plaza Shopping Center         Affton             63123
# ...

# %% [markdown]
# Reviews

# %%
df_reviews
# Out:
#                       review_id                 user_id  \
# 0        KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA
# 1        BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q
# 2        saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A
# 3        AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 4        Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ
# ...                         ...                     ...
# 6990275  H0RIamZu0B0Ei0P4aeh3sQ  qskILQ3k0I_qcCMI-k6_QQ
# 6990276  shTPgbgdwTHSuU67mGCmZQ  Zo0th2m8Ez4gLSbHftiQvg
# 6990277  YNfNhgZlaaCO5Q_YJR4rEw  mm6E4FbCMwJmb7kPDZ5v2Q
# 6990278  i-I4ZOhoX70Nw5H0FwrQUA  YwAMC-jvZ1fvEUum6QkEkw
# 6990279  RwcKOdEuLRHNJe4M9-qpqg  6JehEvdoCvZPJ_XIxnzIIw
#
#                     business_id  stars  useful  funny  cool  \
# 0        XQfwVwDr-v0ZS3_CbbE5Xw      3       0      0     0
# 1        7ATYjTIgM3jUlt4UM3IypQ      5       1      0     1
# 2        YjUWPpI6HXG530lwP-fb2A      3       0      0     0
# ...

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6990280 entries, 0 to 6990279
# Data columns (total 9 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   review_id    object
#  1   user_id      object
#  2   business_id  object
#  3   stars        int64
#  4   useful       int64
#  5   funny        int64
#  6   cool         int64
#  7   text         object
#  8   date         datetime64[ns]
# dtypes: datetime64[ns](1), int64(4), object(4)
# memory usage: 480.0+ MB

# %%
df_reviews.describe()
# Out:
#               stars        useful         funny          cool  \
# count  6.990280e+06  6.990280e+06  6.990280e+06  6.990280e+06
# mean   3.748584e+00  1.184609e+00  3.265596e-01  4.986175e-01
# min    1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00
# 25%    3.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    4.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    5.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# max    5.000000e+00  1.182000e+03  7.920000e+02  4.040000e+02
# std    1.478705e+00  3.253767e+00  1.688729e+00  2.172460e+00
#
#                                 date
# count                        6990280
# mean   2017-01-11 11:22:33.441780992
# min              2005-02-16 03:23:22
# 25%    2015-01-25 04:53:50.249999872
# 50%              2017-06-03 01:26:07
# 75%    2019-05-23 00:02:46.249999872
# max              2022-01-19 19:48:45
# std                              NaN

# %%
df_reviews.drop(['review_id','user_id'],axis=1,inplace=True)

# %%
df_reviews=df_reviews.loc[df_reviews['date']>='2013-01-01']
df_reviews
# Out:
#                     business_id  stars  useful  funny  cool  \
# 0        XQfwVwDr-v0ZS3_CbbE5Xw      3       0      0     0
# 2        YjUWPpI6HXG530lwP-fb2A      3       0      0     0
# 3        kxX2SOes4o-D3ZQBkiMRfA      5       1      0     1
# 4        e4Vwtrqf-wpJfwesgvdgxQ      4       1      0     1
# 5        04UD14gamNjLY0IDYVhHJg      1       1      2     1
# ...                         ...    ...     ...    ...   ...
# 6990275  jals67o91gcrD4DC81Vk6w      5       1      2     1
# 6990276  2vLksaMmSEcGbjI5gywpZA      5       2      1     2
# 6990277  R1khUUxidqfaJmcpmGd4aw      4       1      0     0
# 6990278  Rr9kKArrMhSLVE9a53q-aA      5       1      0     0
# 6990279  VAeEXLbEcI9Emt9KGYq9aA      3      10      3     7
#
#                                                       text                date
# 0        If you decide to eat here, just be aware it is... 2018-07-07 22:09:11
# 2        Family diner. Had the buffet. Eclectic assortm... 2014-02-05 20:30:30
# ...

# %%
df_reviews['cool'].value_counts()
# Out:
# cool
# 0      4863398
# 1       856272
# 2       234432
# 3        87543
# 4        43098
#         ...
# 171          1
# 184          1
# 166          1
# 190          1
# 304          1
# Name: count, Length: 190, dtype: int64

# %%
df_reviews['funny'].value_counts()
# Out:
# funny
# 0      5307893
# 1       577308
# 2       151923
# 3        61469
# 4        30997
#         ...
# 370          1
# 118          1
# 158          1
# 792          1
# 288          1
# Name: count, Length: 164, dtype: int64

# %%
df_reviews['useful'].value_counts()
# Out:
# useful
# 0      3523987
# 1      1347695
# 2       577024
# 3       279489
# 4       149327
#         ...
# 250          1
# 392          1
# 200          1
# 325          1
# 207          1
# Name: count, Length: 231, dtype: int64

# %%
df_reviews.isna().sum()
# Out:
# business_id    0
# stars          0
# useful         0
# funny          0
# cool           0
# text           0
# date           0
# dtype: int64

# %%
df_reviews.drop(['useful','funny','cool'],axis=1,inplace=True)
# Out:
# C:\Users\Fernando\AppData\Local\Temp\ipykernel_22168\4252631309.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reviews.drop(['useful','funny','cool'],axis=1,inplace=True)

# %%
df_reviews['text'].values
# Out:
# array(["If you decide to eat here, just be aware it is going to take about 2 hours from beginning to end. We have tried it multiple times, because I want to like it! I have been to it's other locations in NJ and never had a bad experience. \n\nThe food is good, but it takes a very long time to come out. The waitstaff is very young, but usually pleasant. We have just had too many experiences where we spent way too long waiting. We usually opt for another diner or restaurant on the weekends, in order to be done quicker.",
#        'Family diner. Had the buffet. Eclectic assortment: a large chicken leg, fried jalape̱o, tamale, two rolled grape leaves, fresh melon. All good. Lots of Mexican choices there. Also has a menu with breakfast served all day long. Friendly, attentive staff. Good place for a casual relaxed meal with no expectations. Next to the Clarion Hotel.',
# ...

# %%
len(df_reviews['business_id'].unique())
# Out:
# 147699

# %%
len(df_business['business_id'].unique())
# Out:
# 150346

# %%
len(df_reviews['text'].unique())
# Out:
# 6176036

# %%
df_reviews['text']=df_reviews['text'].drop_duplicates()
# Out:
# C:\Users\Fernando\AppData\Local\Temp\ipykernel_22168\2495855155.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reviews['text']=df_reviews['text'].drop_duplicates()

# %%
len(df_reviews['text'])
# Out:
# 6191627

# %%
len(df_business['name'].unique())
# Out:
# 114117

# %%
len(df_business['address'].unique())
# Out:
# 122844

# %%
reviews1=df_reviews.head(2000000)
reviews1
# Out:
#                     business_id  stars  \
# 0        XQfwVwDr-v0ZS3_CbbE5Xw      3
# 2        YjUWPpI6HXG530lwP-fb2A      3
# 3        kxX2SOes4o-D3ZQBkiMRfA      5
# 4        e4Vwtrqf-wpJfwesgvdgxQ      4
# 5        04UD14gamNjLY0IDYVhHJg      1
# ...                         ...    ...
# 2270096  8Rj8N102MbhuwW-afz0Yuw      5
# 2270097  q2iS794-52tFAC2ScQFTug      5
# 2270098  MNRGrA2vNcM6dTMAp0gi8Q      1
# 2270102  9siOf-TFHGFrsb9XqRi_Pg      5
# 2270103  uaphuuG9cT69mgOrH7xvww      5
#
#                                                       text                date
# 0        If you decide to eat here, just be aware it is... 2018-07-07 22:09:11
# 2        Family diner. Had the buffet. Eclectic assortm... 2014-02-05 20:30:30
# 3        Wow!  Yummy, different,  delicious.   Our favo... 2015-01-04 00:01:03
# 4        Cute interior and owner (?) gave us tour of up... 2017-01-14 20:54:15
# 5        I am a long term frequent customer of this est... 2015-09-23 23:10:31
# ...

# %%
num_filas = len(df_reviews)
filas_por_archivo = num_filas // 3


df1 = df_reviews.iloc[:filas_por_archivo]
df2 = df_reviews.iloc[filas_por_archivo:2*filas_por_archivo]
df3 = df_reviews.iloc[2*filas_por_archivo:]

# %%
df1
# Out:
#                     business_id  stars  \
# 0        XQfwVwDr-v0ZS3_CbbE5Xw      3
# 2        YjUWPpI6HXG530lwP-fb2A      3
# 3        kxX2SOes4o-D3ZQBkiMRfA      5
# 4        e4Vwtrqf-wpJfwesgvdgxQ      4
# 5        04UD14gamNjLY0IDYVhHJg      1
# ...                         ...    ...
# 2347842  FxyGTyC98dVsVMhPiHXyOQ      5
# 2347843  V8U3lY1XbS1ptSpdmewVKQ      5
# 2347844  0eZBo7TTOUCSB3J5TDpe9Q      5
# 2347845  sB4xcTwwCO8IHiK15VDC_A      4
# 2347846  vfD5568Nt1B_ImDC75fBIQ      2
#
#                                                       text                date
# 0        If you decide to eat here, just be aware it is... 2018-07-07 22:09:11
# 2        Family diner. Had the buffet. Eclectic assortm... 2014-02-05 20:30:30
# 3        Wow!  Yummy, different,  delicious.   Our favo... 2015-01-04 00:01:03
# 4        Cute interior and owner (?) gave us tour of up... 2017-01-14 20:54:15
# 5        I am a long term frequent customer of this est... 2015-09-23 23:10:31
# ...

# %%
df2
# Out:
#                     business_id  stars  \
# 2347847  5qWdftveruKnOJ9FKXcGcA      4
# 2347848  uizQiDP3fYaDvCxuwMaSew      3
# 2347849  ZW5RwyoMuAjXsAsrHxMv3w      5
# 2347850  -OKB11ypR4C8wWlonBFIGw      4
# 2347851  qKg3Vu-be1PExiSOX6pTqg      4
# ...                         ...    ...
# 4681317  SVSCKLwC4i2_aanRxSRyMQ      1
# 4681318  SFnJ3vbKhQ_4F3KLG9T4Vw      3
# 4681319  Eb1XmmLWyt_way5NNZ7-Pw      4
# 4681320  ElGUIKG1-4h40_7N9pAU4w      4
# 4681321  rDWA-4RvzzxCLfJwh9NwZw      2
#
#                                                       text                date
# 2347847  I surprised my husband with a res here for his... 2016-07-30 19:15:06
# 2347848  I really wanted to like this place, but it's n... 2014-09-02 20:26:31
# 2347849  Sean, Rowe, Danny, Nicole, and the rest of the... 2013-07-24 00:14:36
# 2347850  This review is for seafood restaurant.  It's v... 2017-11-05 17:34:26
# 2347851  Very fun decorations! You use a clean grease r... 2018-03-13 01:18:02
# ...

# %%
df3
# Out:
#                     business_id  stars  \
# 4681322  IPNAySCrfEUTBnxh1kZq4A      5
# 4681323  1RUStfReoIm_8NzWXKSbCA      3
# 4681324  iW3Jo9r_y671fXCBa3uXeA      5
# 4681325  BuQGsltd3B4L_HRCP2jpTQ      4
# 4681326  OShX8J6CivYAjmzY--QzHA      5
# ...                         ...    ...
# 6990275  jals67o91gcrD4DC81Vk6w      5
# 6990276  2vLksaMmSEcGbjI5gywpZA      5
# 6990277  R1khUUxidqfaJmcpmGd4aw      4
# 6990278  Rr9kKArrMhSLVE9a53q-aA      5
# 6990279  VAeEXLbEcI9Emt9KGYq9aA      3
#
#                                                       text                date
# 4681322  Brent is a true healer. His bodywork is transf... 2021-03-13 19:13:56
# 4681323  The restaurant has a very city bar vibe, with ... 2021-11-02 00:47:26
# 4681324  My guy and I love their juices and smoothies. ... 2021-11-02 20:28:29
# 4681325  If you want southern food in the garden distri... 2021-04-01 22:50:30
# 4681326  I've been to this store 4 different times over... 2021-01-22 21:17:22
# ...

# %%
#df1.to_csv('reviews_parte1.csv', index=False)
#df2.to_csv('reviews_parte2.csv', index=False)
#df3.to_csv('reviews_parte3.csv', index=False)

# %%
#df_business.to_csv('business_yelp.csv',index=False)
